# %%
import pandas as pd
import ssl
import plotly.express as px
import statistics

# %%
dataframe1 = pd.read_excel('/Users/aerdenizmenli/Documents/NewDataSamples.xlsx')

# %%
dataframe1
# Out:
#              Time                       Event                  Touchpoint  \
# 0            DAY1                         NaN                         NaN
# 1   7/26 10.00 AM  Onboarding Account Success                     Onboard
# 2   7/26 10.30 AM               Login Success                       Login
# 3   7/26 10.50 AM              Logout Success                      Logout
# 4            DAY2                         NaN                         NaN
# 5   7/27 10.00 AM               Login Success                       Login
# 6   7/27 10.30 AM            Add Card Failure                    Add Card
# 7   7/27 11.00 AM    Help Center Article Page    Self Service Help Center
# 8   7/27 11.30 AM                   Live Chat            Chat Interaction
# 9   7/27 12.00 PM            Add Card Success                    Add Card
# 10  7/27 12.15 PM              Logout Success                      Logout
# 11           DAY3                         NaN                         NaN
# ...

# %%
data = {
    'WidgetA': [10, 9, 7, 8], 
    'WidgetB': [11, 12, 30, 1]
}

#And then pass it to the pandas DataFrame constructor total_widgets

total_widgets = None

# YOUR CODE HERE
df = pd.DataFrame(data)
total_widgets = df


#Printing the total widgets 
print(total_widgets)
# Out:
#    WidgetA  WidgetB
# 0       10       11
# 1        9       12
# 2        7       30
# 3        8        1

# %%
dataframe1.loc[0:3,['Time','Journey']]
# Out:
#             Time        Journey
# 0           DAY1            NaN
# 1  7/26 10.00 AM  PayPal Core\t
# 2  7/26 10.30 AM  PayPal Core\t
# 3  7/26 10.50 AM  PayPal Core\t

# %%
help(pd.crosstab)
# Out:
# Help on function crosstab in module pandas.core.reshape.pivot:
#
# crosstab(index, columns, values=None, rownames=None, colnames=None, aggfunc=None, margins=False, margins_name: 'str' = 'All', dropna: 'bool' = True, normalize=False) -> 'DataFrame'
#     Compute a simple cross tabulation of two (or more) factors. By default
#     computes a frequency table of the factors unless an array of values and an
#     aggregation function are passed.
#
#     Parameters
#     ----------
#     index : array-like, Series, or list of arrays/Series
#         Values to group by in the rows.
#     columns : array-like, Series, or list of arrays/Series
#         Values to group by in the columns.
#     values : array-like, optional
#         Array of values to aggregate according to the factors.
#         Requires `aggfunc` be specified.
#     rownames : sequence, default None
#         If passed, must match number of row arrays passed.
#     colnames : sequence, default None
# ...

# %%
ssl._create_default_https_context = ssl._create_unverified_context

# %%
df1 = pd.read_excel('https://github.com/SavioSal/datasets/raw/master/World_Bank_CO2.xlsx', sheet_name=None)

# %%
df1
# Out:
# {'About': Empty DataFrame
#  Columns: [Data from http://data.worldbank.org/indicator/EN.ATM.CO2E.PC and http://data.worldbank.org/indicator/EN.ATM.CO2E.KT both last updated 02/05/2016]
#  Index: [],
#  'CO2 (kt) Pivoted':       Country Name Country Code                     Region  Year  CO2 (kt)
#  0            Aruba          ABW  Latin America & Caribbean  1960       NaN
#  1            Aruba          ABW  Latin America & Caribbean  1961       NaN
#  2            Aruba          ABW  Latin America & Caribbean  1962       NaN
#  3            Aruba          ABW  Latin America & Caribbean  1963       NaN
#  4            Aruba          ABW  Latin America & Caribbean  1964       NaN
#  ...            ...          ...                        ...   ...       ...
#  11122     Zimbabwe          ZWE         Sub-Saharan Africa  2007   9732.22
#  11123     Zimbabwe          ZWE         Sub-Saharan Africa  2008   7682.37
# ...

# %%
type(df1)
# Out:
# dict

# %%
df1.keys()
# Out:
# dict_keys(['About', 'CO2 (kt) Pivoted', 'CO2 (kt) RAW DATA', 'CO2 Data Cleaned', 'CO2 (kt) for Split', 'CO2 for World to Union', 'CO2 Per Capita RAW DATA', 'CO2 Per Capita (Pivoted)', 'Metadata - Countries'])

# %%
df1['CO2 (kt) RAW DATA']
# Out:
#          Country Name Country Code      Indicator Name  Indicator Code  \
# 0               Aruba          ABW  CO2 emissions (kt)  EN.ATM.CO2E.KT
# 1             Andorra          AND  CO2 emissions (kt)  EN.ATM.CO2E.KT
# 2         Afghanistan          AFG  CO2 emissions (kt)  EN.ATM.CO2E.KT
# 3              Angola          AGO  CO2 emissions (kt)  EN.ATM.CO2E.KT
# 4             Albania          ALB  CO2 emissions (kt)  EN.ATM.CO2E.KT
# ..                ...          ...                 ...             ...
# 243       Yemen, Rep.          YEM  CO2 emissions (kt)  EN.ATM.CO2E.KT
# 244      South Africa          ZAF  CO2 emissions (kt)  EN.ATM.CO2E.KT
# 245  Congo, Dem. Rep.          COD  CO2 emissions (kt)  EN.ATM.CO2E.KT
# 246            Zambia          ZMB  CO2 emissions (kt)  EN.ATM.CO2E.KT
# 247          Zimbabwe          ZWE  CO2 emissions (kt)  EN.ATM.CO2E.KT
#
#           1960        1961        1962        1963        1964        1965  \
# ...

# %%
[str(y) for y in range(1960,2016)]

# %%
df3=df1['CO2 (kt) RAW DATA'].melt(id_vars = ['Country Name','Country Code','Indicator Name','Indicator Code'],
                              value_vars=[str(y) for y in range(1960,2016)],
                             var_name ='Year',
                             value_name = 'CO2 Level')

# %%
df1['CO2 (kt) Pivoted']
# Out:
#       Country Name Country Code                     Region  Year  CO2 (kt)
# 0            Aruba          ABW  Latin America & Caribbean  1960       NaN
# 1            Aruba          ABW  Latin America & Caribbean  1961       NaN
# 2            Aruba          ABW  Latin America & Caribbean  1962       NaN
# 3            Aruba          ABW  Latin America & Caribbean  1963       NaN
# 4            Aruba          ABW  Latin America & Caribbean  1964       NaN
# ...            ...          ...                        ...   ...       ...
# 11122     Zimbabwe          ZWE         Sub-Saharan Africa  2007   9732.22
# 11123     Zimbabwe          ZWE         Sub-Saharan Africa  2008   7682.37
# 11124     Zimbabwe          ZWE         Sub-Saharan Africa  2009   8239.75
# 11125     Zimbabwe          ZWE         Sub-Saharan Africa  2010   9028.15
# 11126     Zimbabwe          ZWE         Sub-Saharan Africa  2011   9860.56
#
# [11127 rows x 5 columns]

# %%
df1['CO2 (kt) Pivoted'].groupby(['Region','Year']).sum().reset_index()
# Out:
#                   Region  Year     CO2 (kt)
# 0    East Asia & Pacific  1960  1177136.334
# 1    East Asia & Pacific  1961  1010533.536
# 2    East Asia & Pacific  1962   917919.767
# 3    East Asia & Pacific  1963   959463.219
# 4    East Asia & Pacific  1964  1010929.566
# ..                   ...   ...          ...
# 359   Sub-Saharan Africa  2007   686444.071
# 360   Sub-Saharan Africa  2008   717067.185
# 361   Sub-Saharan Africa  2009   711368.716
# 362   Sub-Saharan Africa  2010   713656.882
# 363   Sub-Saharan Africa  2011   746186.864
#
# [364 rows x 3 columns]

# %%
df2
# Out:
#            Country Name Country Code      Indicator Name  Indicator Code  \
# 0                 Aruba          ABW  CO2 emissions (kt)  EN.ATM.CO2E.KT
# 1               Andorra          AND  CO2 emissions (kt)  EN.ATM.CO2E.KT
# 2           Afghanistan          AFG  CO2 emissions (kt)  EN.ATM.CO2E.KT
# 3                Angola          AGO  CO2 emissions (kt)  EN.ATM.CO2E.KT
# 4               Albania          ALB  CO2 emissions (kt)  EN.ATM.CO2E.KT
# ...                 ...          ...                 ...             ...
# 13883       Yemen, Rep.          YEM  CO2 emissions (kt)  EN.ATM.CO2E.KT
# 13884      South Africa          ZAF  CO2 emissions (kt)  EN.ATM.CO2E.KT
# 13885  Congo, Dem. Rep.          COD  CO2 emissions (kt)  EN.ATM.CO2E.KT
# 13886            Zambia          ZMB  CO2 emissions (kt)  EN.ATM.CO2E.KT
# 13887          Zimbabwe          ZWE  CO2 emissions (kt)  EN.ATM.CO2E.KT
#
#        Year  CO2 Level
# 0      1960        NaN
# 1      1960        NaN
# ...

# %%
fig = px.line(df2, x='Year', y='CO2 Level', color='Country Name')
fig.show()
# Out:
# <div>                            <div id="543371b5-3f34-42f1-87bf-252664bd53af" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("543371b5-3f34-42f1-87bf-252664bd53af")) {                    Plotly.newPlot(                        "543371b5-3f34-42f1-87bf-252664bd53af",                        [{"hovertemplate":"Country Name=Aruba<br>Year=%{x}<br>CO2 Level=%{y}<extra></extra>","legendgroup":"Aruba","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"Aruba","showlegend":true,"x":["1960","1961","1962","1963","1964","1965","1966","1967","1968","1969","1970","1971","1972","1973","1974","1975","1976","1977","1978","1979","1980","1981","1982","1983","1984","1985","1986","1987","1988","1989","1990","1991","1992","1993"
# ...

# %%
px.line(df1['CO2 (kt) Pivoted'].groupby(['Region','Year']).sum().reset_index(),
        x='Year', y='CO2 (kt)', color='Region')
# Out:
# <div>                            <div id="d8b57862-b82a-4fae-a372-d56294bff5d7" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("d8b57862-b82a-4fae-a372-d56294bff5d7")) {                    Plotly.newPlot(                        "d8b57862-b82a-4fae-a372-d56294bff5d7",                        [{"hovertemplate":"Region=East Asia & Pacific<br>Year=%{x}<br>CO2 (kt)=%{y}<extra></extra>","legendgroup":"East Asia & Pacific","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"East Asia & Pacific","orientation":"v","showlegend":true,"x":[1960,1961,1962,1963,1964,1965,1966,1967,1968,1969,1970,1971,1972,1973,1974,1975,1976,1977,1978,1979,1980,1981,1982,1983,1984,1985,1986,1987,1988,1989,1990,1991,1992,1993,1994,1995,1996
# ...

# %%
px.line(df1['CO2 (kt) Pivoted'].query('`Country Name` == "China"').groupby(['Region','Year']).sum().reset_index(),
        x='Year', y='CO2 (kt)', color='Region')
# Out:
# <div>                            <div id="a4a860cb-525e-416f-a845-9cd198392b28" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("a4a860cb-525e-416f-a845-9cd198392b28")) {                    Plotly.newPlot(                        "a4a860cb-525e-416f-a845-9cd198392b28",                        [{"hovertemplate":"Region=East Asia & Pacific<br>Year=%{x}<br>CO2 (kt)=%{y}<extra></extra>","legendgroup":"East Asia & Pacific","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"East Asia & Pacific","orientation":"v","showlegend":true,"x":[1960,1961,1962,1963,1964,1965,1966,1967,1968,1969,1970,1971,1972,1973,1974,1975,1976,1977,1978,1979,1980,1981,1982,1983,1984,1985,1986,1987,1988,1989,1990,1991,1992,1993,1994,1995,1996
# ...

# %%
india = pd.read_html('https://en.wikipedia.org/wiki/States_and_union_territories_of_India')

# %%
india
# Out:
# [               States and union territories of India  \
#  0  Andhra Pradesh Arunachal Pradesh Assam Bihar C...
#  1                                           Category
#  2                                           Location
#  3                                             Number
#  4                                        Populations
#  5                                              Areas
#  6                                         Government
#  7                                       Subdivisions
#
#               States and union territories of India.1
#  0  Andhra Pradesh Arunachal Pradesh Assam Bihar C...
#  1                                   Federated states
#  2                                  Republic of India
#  3                       28 States8 Union territories
#  4  States: Sikkim - 610,577 (lowest); Uttar Prade...
#  5  States: Goa - 3,702 km2 (1,429 sq mi); Rajasth...
#  6  State governmentsUnion governments (union terr...
# ...

# %%
type(india)
# Out:
# list

# %%
india[0]
# Out:
#                States and union territories of India  \
# 0  Andhra Pradesh Arunachal Pradesh Assam Bihar C...
# 1                                           Category
# 2                                           Location
# 3                                             Number
# 4                                        Populations
# 5                                              Areas
# 6                                         Government
# 7                                       Subdivisions
#
#              States and union territories of India.1
# 0  Andhra Pradesh Arunachal Pradesh Assam Bihar C...
# 1                                   Federated states
# 2                                  Republic of India
# 3                       28 States8 Union territories
# 4  States: Sikkim - 610,577 (lowest); Uttar Prade...
# 5  States: Goa - 3,702 km2 (1,429 sq mi); Rajasth...
# 6  State governmentsUnion governments (union terr...
# 7                                 DivisionsDistricts

# %%
len(india)
# Out:
# 11

# %%
for table in india:
    if 'Officiallanguages' in table:
        india_table = table
        #print(table)

# %%
india_table
# Out:
#                             Union territory ISO 3166-2:IN Vehiclecode  \
# 0               Andaman and Nicobar Islands         IN-AN          AN
# 1                                Chandigarh         IN-CH          CH
# 2  Dadra and Nagar Haveli and Daman and Diu         IN-DH          DD
# 3                                     Delhi         IN-DL          DL
# 4                        Jammu  and Kashmir         IN-JK          JK
# 5                                    Ladakh         IN-LA          LA
# 6                               Lakshadweep         IN-LD          LD
# 7                                Puducherry         IN-PY          PY
#
#        Zone                                          Capital Largest city  \
# 0  Southern                                       Port Blair   Port Blair
# 1  Northern                                       Chandigarh            —
# 2   Western                                            Daman        Daman
# ...

# %%
# analyze data points for outliers - mode is one method
statistics.mode(india_table['Area(km2)'])
# Out:
# 8249

# %%
india_table['Area(km2)'].mean()
# Out:
# 14045.875

# %%
india_table['Area(km2)'].median()
# Out:
# 1046.5

# %%
lotto = pd.read_html('https://www.texaslottery.org/export/sites/lottery/Games/Powerball/Winning_Numbers/')
# Out:
# ---------------------------------------------------------------------------
# ConnectionResetError                      Traceback (most recent call last)
# /Applications/anaconda3/lib/python3.9/urllib/request.py in do_open(self, http_class, req, **http_conn_args)
#    1345             try:
# -> 1346                 h.request(req.get_method(), req.selector, req.data, headers,
#    1347                           encode_chunked=req.has_header('Transfer-encoding'))
#
# /Applications/anaconda3/lib/python3.9/http/client.py in request(self, method, url, body, headers, encode_chunked)
#    1278         """Send a complete request to the server."""
# -> 1279         self._send_request(method, url, body, headers, encode_chunked)
#    1280
#
# /Applications/anaconda3/lib/python3.9/http/client.py in _send_request(self, method, url, body, headers, encode_chunked)
#    1324             body = _encode(body, 'body')
# -> 1325         self.endheaders(body, encode_chunked=encode_chunked)
#    1326
#
# ...

# %%
type(lotto)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /var/folders/y8/q3tyf2ls6hdcr5jmw1zdr2f40000gp/T/ipykernel_71592/2397762250.py in <module>
# ----> 1 type(lotto)
#
# NameError: name 'lotto' is not defined
