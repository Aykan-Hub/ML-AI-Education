# %% [markdown]
# ### Codio Activity 18.2: Named Entities
#
# **Expected Time = 45 minutes**
#
# **Total Points = 30**
#
# This activity focuses on extracting named entities from text.  The named entities will be extracted using the `nltk` library.  You will read in the full text of Newton's *Principia* and identify the entities labeled as places.
#
# #### Index
#
# - [Problem 1](#-Problem-1)
# - [Problem 2](#-Problem-2)
# - [Problem 3](#-Problem-3)
# - [Problem 4](#-Problem-4)
# - [Problem 5](#-Problem-5)
# - [Problem 6](#-Problem-6)

# %%
import ssl
ssl._create_default_https_context = ssl._create_unverified_context

# %%
import nltk
from nltk import word_tokenize
nltk.download('punkt')
nltk.download('averaged_perceptron_tagger')
nltk.download('maxent_ne_chunker')
nltk.download('words')
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     /Users/aerdenizmenli/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /Users/aerdenizmenli/nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!
# [nltk_data] Downloading package maxent_ne_chunker to
# [nltk_data]     /Users/aerdenizmenli/nltk_data...
# [nltk_data]   Package maxent_ne_chunker is already up-to-date!
# [nltk_data] Downloading package words to
# [nltk_data]     /Users/aerdenizmenli/nltk_data...
# [nltk_data]   Package words is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /Users/aerdenizmenli/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %% [markdown]
# [Back to top](#-Index)
#
# ### Problem 1
#
# #### Opening a `.txt` file.
#
# **5 Points**
#
# Use the `open` function to open the text file with the Principia by Isaac Newton using the filepath given below.  Assign the text using the `readlines()` function to assign the text as a list of lines to the variable `principia` below.

# %%
filepath = 'data/Philosophiae_Naturalis_Principia_Mathematica.txt'

# %%
### GRADED
with open(filepath) as f:
    principia = ''

    
# YOUR CODE HERE
#raise NotImplementedError()
with open(filepath) as f:
    principia = f.readlines()


### ANSWER CHECK
print(type(principia))
# Out:
# <class 'list'>

# %% [markdown]
# [Back to top](#-Index)
#
# ### Problem 2
#
# #### Tokenizing the text.
#
# **5 Points**
#
# Using the `principia` variable from problem 1, combine the `' '.join()` function with `word_tokenize` to create a list of tokens named `tokens` below.

# %%
#word_tokenize(' '.join(principia))

# %%
### GRADED
tokens = ''

    
# YOUR CODE HERE
#raise NotImplementedError()
tokens = word_tokenize(' '.join(principia))

### ANSWER CHECK
print(type(tokens))
print(tokens[:5])
# Out:
# <class 'list'>
# ['Philosophiae', 'Naturalis', 'Principia', 'Mathematica', 'Isaacus']

# %% [markdown]
# [Back to top](#-Index)
#
# ### Problem 3
#
# #### Part of Speech Tags
#
# **5 Points**
#
# Use the `pos_tag` function to create the part of speech tagged corpus of the principia text.  Assign the tagged text to the variable `words_pos` below.

# %%
### GRADED
words_pos = ''

    
# YOUR CODE HERE
#raise NotImplementedError()
words_pos = nltk.pos_tag(tokens)

### ANSWER CHECK
print(type(words_pos))
print(words_pos[:5])
# Out:
# <class 'list'>
# [('Philosophiae', 'NNP'), ('Naturalis', 'NNP'), ('Principia', 'NNP'), ('Mathematica', 'NNP'), ('Isaacus', 'NNP')]

# %% [markdown]
# [Back to top](#-Index)
#
# ### Problem 4
#
# #### Named Entities
#
# **5 Points**
#
# Use the tagged words in `words_pos` to create a list of tuples in the form (word, entity type) if the word has a named entity label.  Assign these tuples to the list `named_entities` below.

# %%
tuple(words_pos)
# Out:
# (('Philosophiae', 'NNP'),
#  ('Naturalis', 'NNP'),
#  ('Principia', 'NNP'),
#  ('Mathematica', 'NNP'),
#  ('Isaacus', 'NNP'),
#  ('Newtonus', 'NNP'),
#  ('1687', 'CD'),
#  ('Exported', 'NNP'),
#  ('from', 'IN'),
#  ('Wikisource', 'NNP'),
#  ('on', 'IN'),
#  ('April', 'NNP'),
#  ('3', 'CD'),
#  (',', ','),
#  ('2022', 'CD'),
#  ('INDEX', 'NNP'),
#  ('Tituli', 'NNP'),
#  ('pagina', 'VBZ'),
#  ('Auctoris', 'NNP'),
#  ('præfatio', 'NN'),
#  ('ad', 'NN'),
#  ('lectorem', 'NN'),
#  ('Viri', 'NNP'),
#  ('Præstantissimi', 'NNP'),
#  ('Definitiones', 'NNP'),
#  ('Axiomata', 'NNP'),
#  (',', ','),
#  ('sive', 'JJ'),
#  ('Leges', 'NNP'),
#  ('Motus', 'NNP'),
#  ('DE', 'NNP'),
#  ('MOTU', 'NNP'),
#  ('CORPORUM', 'NNP'),
#  ('LIBER', 'NNP'),
#  ('PRIMUS', 'NNP'),
#  ('SECT', 'NNP'),
#  ('.', '.'),
#  ('I', 'PRP'),
#  ('.', '.'),
#  ('DE', 'NNP'),
#  ('Methodo', 'NNP'),
#  ('rationum', 'NN'),
#  ('primarum', 'NN'),
#  ('&', 'CC'),
#  ('ultima', 'JJ'),
#  ('rum', 'NN'),
#  ('.', '.'),
#  ('SECT', 'NNP'),
#  ('.', '.'),
#  ('II', 'NNP'),
#  ('.', '.'),
#  ('De', 'NNP'),
#  ('inventione', 'NN'),
#  ('Virium', 'NNP'),
#  ('centripetarum', 'NN'),
#  ('.', '.'),
#  ('SECT', 'NNP'),
#  ('.', '.'),
#  ('III', 'NNP'),
#  ('.', '.'),
#  ('De', 'NNP'),
#  ('motu', 'FW'),
#  ('corporum', 'NN'),
#  ('in', 'IN'),
#  ('Conicis', 'NNP'),
#  ('sectionibus', 'NN'),
#  ('eccentri', 'NN'),
#  ('cis', 'NN'),
#  ('.', '.'),
#  ('SECT', 'NNP'),
#  ('.', '.'),
#  ('IV', 'NNP'),
#  ('.', '.'),
#  ('De', 'NNP'),
#  ('inventione', 'NN'),
#  ('Orbium', 'NNP'),
#  ('Elliptieorum', 'NNP'),
#  (',', ','),
#  ('Parabolieorum', 'NNP'),
#  ('&', 'CC'),
#  ('Hyperbolieorum', 'NNP'),
#  ('ex', 'VBP'),
#  ('Umbilico', 'NNP'),
#  ('dato', 'NN'),
#  ('.', '.'),
#  ('SECT', 'NNP'),
#  ('.', '.'),
#  ('V.', 'NNP'),
#  ('De', 'NNP'),
#  ('inventione', 'NN'),
#  ('Orbium', 'NNP'),
#  ('ubi', 'JJ'),
#  ('Umbilicus', 'NNP'),
#  ('neuter', 'NN'),
#  ('datur', 'NN'),
#  ('.', '.'),
#  ('SECT', 'NNP'),
#  ('.', '.'),
#  ('VI', 'NNP'),
#  ('.', '.'),
#  ('De', 'NNP'),
#  ('inventione', 'NN'),
#  ('Motuum', 'NNP'),
#  ('in', 'IN'),
#  ('Orbibus', 'NNP'),
#  ('datis', 'NN'),
#  ('.', '.'),
#  ('SECT', 'NNP'),
#  ('.', '.'),
#  ('VII', 'NNP'),
#  ('.', '.'),
#  ('De', 'NNP'),
#  ('corporum', 'NN'),
#  ('Ascensu', 'NNP'),
#  ('&', 'CC'),
#  ('Descensu', 'NNP'),
#  ('rectilineo', 'NN'),
#  ('.', '.'),
#  ('SECT', 'NNP'),
#  ('.', '.'),
#  ('VIII', 'NNP'),
#  ('.', '.'),
#  ('De', 'NNP'),
#  ('inventione', 'NN'),
#  ('Orbium', 'NNP'),
#  ('in', 'IN'),
#  ('quibus', 'NN'),
#  ('corpora', 'NN'),
#  ('Viribus', 'NNP'),
#  ('quibuscunque', 'NN'),
#  ('centripetis', 'NN'),
#  ('agitata', 'NN'),
#  ('revolvuntur', 'NN'),
#  ('.', '.'),
#  ('SECT', 'NNP'),
#  ('.', '.'),
#  ('IX', 'NNP'),
#  ('.', '.'),
#  ('De', 'NNP'),
#  ('Motu', 'NNP'),
#  ('corporum', 'NN'),
#  ('in', 'IN'),
#  ('Orbibus', 'NNP'),
#  ('mobilibus', 'NN'),
#  (',', ','),
#  ('deque', 'NN'),
#  ('Motu', 'NNP'),
#  ('Apsidum', 'NNP'),
#  ('.', '.'),
#  ('SECT', 'NNP'),
#  ('.', '.'),
#  ('X', 'NNP'),
#  ('.', '.'),
#  ('De', 'NNP'),
#  ('Motu', 'NNP'),
#  ('corporum', 'NN'),
#  ('in', 'IN'),
#  ('Superficiebus', 'NNP'),
#  ('datis', 'NN'),
#  (',', ','),
#  ('deque', 'NN'),
#  ('Funependulorum', 'NNP'),
#  ('Motu', 'NNP'),
#  ('reciproco', 'NN'),
#  ('.', '.'),
#  ('SECT', 'NNP'),
#  ('.', '.'),
#  ('XI', 'NNP'),
#  ('.', '.'),
#  ('De', 'NNP'),
#  ('Motu', 'NNP'),
#  ('corporum', 'NN'),
#  ('Viribus', 'NNP'),
#  ('centripetis', 'NN'),
#  ('se', 'NN'),
#  ('mutuo', 'NN'),
#  ('pe', 'NN'),
#  ('tentium', 'NN'),
#  ('.', '.'),
#  ('SECT', 'NNP'),
#  ('.', '.'),
#  ('XII', 'NNP'),
#  ('.', '.'),
#  ('De', 'NNP'),
#  ('corporum', 'NN'),
#  ('Sphærieorum', 'NNP'),
#  ('Viribus', 'NNP'),
#  ('attractivis', 'NN'),
#  ('.', '.'),
#  ('SECT', 'NNP'),
#  ('.', '.'),
#  ('XIII', 'NNP'),
#  ('.', '.'),
#  ('De', 'NNP'),
#  ('corporum', 'NN'),
#  ('non', 'NN'),
#  ('Sphærieorum', 'NNP'),
#  ('Viribus', 'NNP'),
#  ('attracti', 'NN'),
#  ('vis', 'NN'),
#  ('.', '.'),
#  ('SECT', 'NNP'),
#  ('.', '.'),
#  ('XIV', 'NNP'),
#  ('.', '.'),
#  ('De', 'NNP'),
#  ('Motu', 'NNP'),
#  ('corporum', 'NN'),
#  ('Minimorum', 'NNP'),
#  (',', ','),
#  ('quæ', 'NN'),
#  ('Veribus', 'NNP'),
#  ('cen', 'NN'),
#  ('tripetis', 'NN'),
#  ('ad', 'NN'),
#  ('singulas', 'NN'),
#  ('Magni', 'NNP'),
#  ('alicujus', 'VBZ'),
#  ('corporis', 'NN'),
#  ('partes', 'NNS'),
#  ('ten', 'VBP'),
#  ('dentibus', 'JJ'),
#  ('agitantur', 'NN'),
#  ('.', '.'),
#  ('DE', 'NNP'),
#  ('MOTU', 'NNP'),
#  ('CORPORUM', 'NNP'),
#  ('LIBER', 'NNP'),
#  ('SECUNDUS', 'NNP'),
#  ('.', '.'),
#  ('SECT', 'NNP'),
#  ('.', '.'),
#  ('I', 'PRP'),
#  ('.', '.'),
#  ('De', 'NNP'),
#  ('Motu', 'NNP'),
#  ('corporum', 'NN'),
#  ('quibus', 'NN'),
#  ('resistitur', 'NN'),
#  ('in', 'IN'),
#  ('ratione', 'NN'),
#  ('velocitatis', 'NN'),
#  ('.', '.'),
#  ('SECT', 'NNP'),
#  ('.', '.'),
#  ('II', 'NNP'),
#  ('.', '.'),
#  ('De', 'NNP'),
#  ('motu', 'FW'),
#  ('corporum', 'NN'),
#  ('quibus', 'NN'),
#  ('resistitur', 'NN'),
#  ('in', 'IN'),
#  ('duplicata', 'NN'),
#  ('ratione', 'NN'),
#  ('velocitatum', 'NN'),
#  ('.', '.'),
#  ('SECT', 'NNP'),
#  ('.', '.'),
#  ('III', 'NNP'),
#  ('.', '.'),
#  ('De', 'NNP'),
#  ('motu', 'FW'),
#  ('corporum', 'NN'),
#  ('quæ', 'NN'),
#  ('resistuntur', 'NN'),
#  ('partim', 'NN'),
#  ('in', 'IN'),
#  ('ratione', 'NN'),
#  ('velocitatis', 'NN'),
#  (',', ','),
#  ('partim', 'NN'),
#  ('in', 'IN'),
#  ('ejusdem', 'JJ'),
#  ('ratione', 'NN'),
#  ('duplicata', 'NN'),
#  ('.', '.'),
#  ('SECT', 'NNP'),
#  ('.', '.'),
#  ('IV', 'NNP'),
#  ('.', '.'),
#  ('De', 'NNP'),
#  ('Corporum', 'NNP'),
#  ('circulari', 'NN'),
#  ('Motu', 'NNP'),
#  ('in', 'IN'),
#  ('Mediis', 'NNP'),
#  ('resistentibus', 'NN'),
#  ('.', '.'),
#  ('SECT', 'NNP'),
#  ('.', '.'),
#  ('V.', 'NNP'),
#  ('De', 'NNP'),
#  ('Densitate', 'NNP'),
#  ('&', 'CC'),
#  ('compressione', 'NN'),
#  ('Fluidorum', 'NNP'),
#  (',', ','),
#  ('deque', 'NN'),
#  ('Hydrostatica', 'NNP'),
#  ('.', '.'),
#  ('SECT', 'NNP'),
#  ('.', '.'),
#  ('VI', 'NNP'),
#  ('.', '.'),
#  ('De', 'NNP'),
#  ('Motu', 'NNP'),
#  ('&', 'CC'),
#  ('resistentia', 'NN'),
#  ('Corporum', 'NNP'),
#  ('Funependulorum', 'NNP'),
#  ('.', '.'),
#  ('SECT', 'NNP'),
#  ('.', '.'),
#  ('VII', 'NNP'),
#  ('.', '.'),
#  ('De', 'NNP'),
#  ('Motu', 'NNP'),
#  ('Fluidorum', 'NNP'),
#  ('&', 'CC'),
#  ('resistentia', 'NN'),
#  ('Projectilium', 'NN'),
#  ('.', '.'),
#  ('SECT', 'NNP'),
#  ('.', '.'),
#  ('VIII', 'NNP'),
#  ('.', '.'),
#  ('De', 'NNP'),
#  ('Motu', 'NNP'),
#  ('per', 'IN'),
#  ('Fluida', 'NNP'),
#  ('propagato', 'NN'),
#  ('.', '.'),
#  ('SECT', 'NNP'),
#  ('.', '.'),
#  ('IX', 'NNP'),
#  ('.', '.'),
#  ('De', 'NNP'),
#  ('motu', 'FW'),
#  ('Circulari', 'NNP'),
#  ('Fluidorum', 'NNP'),
#  ('.', '.'),
#  ('DI', 'NNP'),
#  ('MUNDI', 'NNP'),
#  ('SYSTEMATE', 'NNP'),
#  ('LIBER', 'NNP'),
#  ('TERTIUS', 'NNP'),
#  ('.', '.'),
#  ('APPENDIX', 'NNP'),
#  ('The', 'DT'),
#  ('Project', 'NNP'),
#  ('Gutenberg', 'NNP'),
#  ('EBook', 'NNP'),
#  ('of', 'IN'),
#  ('Philosophiae', 'NNP'),
#  ('Naturalis', 'NNP'),
#  ('Principia', 'NNP'),
#  ('Mathematica', 'NNP'),
#  (',', ','),
#  ('by', 'IN'),
#  ('Isaac', 'NNP'),
#  ('Newton', 'NNP'),
#  ('This', 'DT'),
#  ('eBook', 'NN'),
#  ('is', 'VBZ'),
#  ('for', 'IN'),
#  ('the', 'DT'),
#  ('use', 'NN'),
#  ('of', 'IN'),
#  ('anyone', 'NN'),
#  ('anywhere', 'RB'),
#  ('at', 'IN'),
#  ('no', 'DT'),
#  ('cost', 'NN'),
#  ('and', 'CC'),
#  ('with', 'IN'),
#  ('almost', 'RB'),
#  ('no', 'DT'),
#  ('restrictions', 'NNS'),
#  ('whatsoever', 'RB'),
#  ('.', '.'),
#  ('You', 'PRP'),
#  ('may', 'MD'),
#  ('copy', 'VB'),
#  ('it', 'PRP'),
#  (',', ','),
#  ('give', 'VB'),
#  ('it', 'PRP'),
#  ('away', 'RB'),
#  ('or', 'CC'),
#  ('re', 'VB'),
#  ('use', 'IN'),
#  ('it', 'PRP'),
#  ('under', 'IN'),
#  ('the', 'DT'),
#  ('terms', 'NNS'),
#  ('of', 'IN'),
#  ('the', 'DT'),
#  ('Project', 'NNP'),
#  ('Gutenberg', 'NNP'),
#  ('License', 'NNP'),
#  ('included', 'VBD'),
#  ('with', 'IN'),
#  ('this', 'DT'),
#  ('eBook', 'NN'),
#  ('or', 'CC'),
#  ('online', 'NN'),
#  ('at', 'IN'),
#  ('www.gutenberg.org', 'JJ'),
#  ('Title', 'NN'),
#  (':', ':'),
#  ('Philosophiae', 'NNP'),
#  ('Naturalis', 'NNP'),
#  ('Principia', 'NNP'),
#  ('Mathematica', 'NNP'),
#  ('Author', 'NNP'),
#  (':', ':'),
#  ('Isaac', 'NNP'),
#  ('Newton', 'NNP'),
#  ('Release', 'NNP'),
#  ('Date', 'NNP'),
#  (':', ':'),
#  ('March', 'NNP'),
#  ('1', 'CD'),
#  (',', ','),
#  ('2009', 'CD'),
#  ('[', 'NNP'),
#  ('EBook', 'NNP'),
#  ('#', '#'),
#  ('28233', 'CD'),
#  (']', 'JJ'),
#  ('Language', 'NN'),
#  (':', ':'),
#  ('Latin', 'JJ'),
#  ('Character', 'NNP'),
#  ('set', 'VBD'),
#  ('encoding', 'NN'),
#  (':', ':'),
#  ('ISO', 'NN'),
#  ('8859', 'CD'),
#  ('1', 'CD'),
#  ('START', 'NNP'),
#  ('OF', 'IN'),
#  ('THIS', 'NNP'),
#  ('PROJECT', 'NNP'),
#  ('GUTENBERG', 'NNP'),
#  ('EBOOK', 'NNP'),
#  ('PHILOSOPHIAE', 'NNP'),
#  ('NATURALIS', 'NNP'),
#  ('Produced', 'NNP'),
#  ('by', 'IN'),
#  ('Jonathan', 'NNP'),
#  ('Ingram', 'NNP'),
#  (',', ','),
#  ('Keith', 'NNP'),
#  ('Edkins', 'NNP'),
#  ('and', 'CC'),
#  ('the', 'DT'),
#  ('Online', 'NNP'),
#  ('Distributed', 'NNP'),
#  ('Proofreading', 'NNP'),
#  ('Team', 'NNP'),
#  ('at', 'IN'),
#  ('http', 'NN'),
#  (':', ':'),
#  ('//www.pgdp.net', 'NN'),
#  ('PHILOSOPHIÆ', 'NNP'),
#  ('NATURALIS', 'NNP'),
#  ('PRINCIPIA', 'NNP'),
#  ('MATHEMATICA', 'NNP'),
#  ('*', 'NNP'),
#  ('*', 'NNP'),
#  ('*', 'NNP'),
#  ('Autore', 'NNP'),
#  ('IS', 'NNP'),
#  ('.', '.'),
#  ('NEWTON', 'NNP'),
#  (',', ','),
#  ('Trin', 'NNP'),
#  ('.', '.'),
#  ('Coll', 'NNP'),
#  ('.', '.'),
#  ('Cantab', 'NNP'),
#  ('.', '.'),
#  ('Soc', 'NNP'),
#  ('.', '.'),
#  ('Matheseos', 'NNP'),
#  ('Professore', 'NNP'),
#  ('Lucasiano', 'NNP'),
#  (',', ','),
#  ('&', 'CC'),
#  ('Societatis', 'NNP'),
#  ('Regalis', 'NNP'),
#  ('Sodali', 'NNP'),
#  ('.', '.'),
#  ('*', 'VB'),
#  ('*', 'JJ'),
#  ('*', 'NNP'),
#  ('IMPRIMATUR', 'NNP'),
#  ('.', '.'),
#  ('S.', 'NNP'),
#  ('PEPYS', 'NNP'),
#  (',', ','),
#  ('Reg', 'NNP'),
#  ('.', '.'),
#  ('Soc', 'NNP'),
#  ('.', '.'),
#  ('PRÆSES', 'NNP'),
#  ('.', '.'),
#  ('Julii', 'NNP'),
#  ('5', 'CD'),
#  ('.', '.'),
#  ('1686', 'CD'),
#  ('.', '.'),
#  ('*', 'VB'),
#  ('*', 'JJ'),
#  ('*', 'NNP'),
#  ('LONDINI', 'NNP'),
#  (',', ','),
#  ('Jussu', 'NNP'),
#  ('Societatis', 'NNP'),
#  ('Regiæ', 'NNP'),
#  ('ac', 'VBZ'),
#  ('Typis', 'NNP'),
#  ('Josephi', 'NNP'),
#  ('Streater', 'NNP'),
#  ('.', '.'),
#  ('Prostat', 'NNP'),
#  ('apud', 'JJ'),
#  ('plures', 'NNS'),
#  ('Bibliopolas', 'NNP'),
#  ('.', '.'),
#  ('Anno', 'NNP'),
#  ('MDCLXXXVII', 'NNP'),
#  ('.', '.'),
#  ('ILLUSTRISSIMÆ', 'NNP'),
#  ('SOCIETATI', 'NNP'),
#  ('REGALI', 'NNP'),
#  ('a', 'DT'),
#  ('Serenissimo', 'NNP'),
#  ('REGE', 'NNP'),
#  ('CAROLO', 'NNP'),
#  ('II', 'NNP'),
#  ('.', '.'),
#  ('AD', 'NNP'),
#  ('PHILOSOPHIAM', 'NNP'),
#  ('PROMOVENDAM', 'NNP'),
#  ('FUNDATÆ', 'NNP'),
#  (',', ','),
#  ('ET', 'NNP'),
#  ('AUSPICIIS', 'NNP'),
#  ('POTENTISSIMI', 'NNP'),
#  ('MONARCHÆ', 'NNP'),
#  ('JACOBI', 'NNP'),
#  ('II', 'NNP'),
#  ('.', '.'),
#  ('FLORENTI', 'NNP'),
#  ('.', '.'),
#  ('Tractatum', 'NNP'),
#  ('hunc', 'NN'),
#  ('humillime', 'NN'),
#  ('D.D.D', 'NNP'),
#  ('.', '.'),
#  ('IS', 'NNP'),
#  ('.', '.'),
#  ('NEWTON', 'NNP'),
#  ('.', '.'),
#  ('About', 'IN'),
#  ('this', 'DT'),
#  ('digital', 'JJ'),
#  ('edition', 'NN'),
#  ('This', 'DT'),
#  ('e-book', 'NN'),
#  ('comes', 'VBZ'),
#  ('from', 'IN'),
#  ('the', 'DT'),
#  ('online', 'JJ'),
#  ('library', 'JJ'),
#  ('Wikisource', 'NNP'),
#  ('[', 'VBD'),
#  ('1', 'CD'),
#  (']', 'NN'),
#  ('.', '.'),
#  ('This', 'DT'),
#  ('multilingual', 'JJ'),
#  ('digital', 'JJ'),
#  ('library', 'NN'),
#  (',', ','),
#  ('built', 'VBN'),
#  ('by', 'IN'),
#  ('volunteers', 'NNS'),
#  (',', ','),
#  ('is', 'VBZ'),
#  ('committed', 'VBN'),
#  ('to', 'TO'),
#  ('developing', 'VBG'),
#  ('a', 'DT'),
#  ('free', 'JJ'),
#  ('accessible', 'JJ'),
#  ('collection', 'NN'),
#  ('of', 'IN'),
#  ('publications', 'NNS'),
#  ('of', 'IN'),
#  ('every', 'DT'),
#  ('kind', 'NN'),
#  (':', ':'),
#  ('novels', 'NNS'),
#  (',', ','),
#  ('poems', 'NNS'),
#  (',', ','),
#  ('magazines', 'NNS'),
#  (',', ','),
#  ('letters', 'NNS'),
#  ('...', ':'),
#  ('We', 'PRP'),
#  ('distribute', 'VBP'),
#  ('our', 'PRP$'),
#  ('books', 'NNS'),
#  ('for', 'IN'),
#  ('free', 'JJ'),
#  (',', ','),
#  ('starting', 'VBG'),
#  ('from', 'IN'),
#  ('works', 'NNS'),
#  ('not', 'RB'),
#  ('copyrighted', 'VBD'),
#  ('or', 'CC'),
#  ('published', 'VBN'),
#  ('under', 'IN'),
#  ('a', 'DT'),
#  ('free', 'JJ'),
#  ('license', 'NN'),
#  ('.', '.'),
#  ('You', 'PRP'),
#  ('are', 'VBP'),
#  ('free', 'JJ'),
#  ('to', 'TO'),
#  ('use', 'VB'),
#  ('our', 'PRP$'),
#  ('e-books', 'NNS'),
#  ('for', 'IN'),
#  ('any', 'DT'),
#  ('purpose', 'NN'),
#  ('(', '('),
#  ('including', 'VBG'),
#  ('commercial', 'JJ'),
#  ('exploitation', 'NN'),
#  (')', ')'),
#  (',', ','),
#  ('under', 'IN'),
#  ('the', 'DT'),
#  ('terms', 'NNS'),
#  ('of', 'IN'),
#  ('the', 'DT'),
#  ('Creative', 'JJ'),
#  ('Commons', 'NNP'),
#  ('Attribution-ShareAlike', 'NNP'),
#  ('3.0', 'CD'),
#  ('Unported', 'NNP'),
#  ('[', 'VBD'),
#  ('2', 'CD'),
#  (']', 'JJ'),
#  ('license', 'NN'),
#  ('or', 'CC'),
#  (',', ','),
#  ('at', 'IN'),
#  ('your', 'PRP$'),
#  ('choice', 'NN'),
#  (',', ','),
#  ('those', 'DT'),
#  ('of', 'IN'),
#  ('the', 'DT'),
#  ('GNU', 'NNP'),
#  ('FDL', 'NNP'),
#  ('[', 'VBD'),
#  ('3', 'CD'),
#  (']', 'NN'),
#  ('.', '.'),
#  ('Wikisource', 'NNP'),
#  ('is', 'VBZ'),
#  ('constantly', 'RB'),
#  ('looking', 'VBG'),
#  ('for', 'IN'),
#  ('new', 'JJ'),
#  ('members', 'NNS'),
#  ('.', '.'),
#  ('During', 'IN'),
#  ('the', 'DT'),
#  ('realization', 'NN'),
#  ('of', 'IN'),
#  ('this', 'DT'),
#  ('book', 'NN'),
#  (',', ','),
#  ('it', 'PRP'),
#  ("'s", 'VBZ'),
#  ('possible', 'JJ'),
#  ('that', 'IN'),
#  ('we', 'PRP'),
#  ('made', 'VBD'),
#  ('some', 'DT'),
#  ('errors', 'NNS'),
#  ('.', '.'),
#  ('You', 'PRP'),
#  ('can', 'MD'),
#  ('report', 'VB'),
#  ('them', 'PRP'),
#  ('at', 'IN'),
#  ('this', 'DT'),
#  ('page', 'NN'),
#  ('[', 'VBZ'),
#  ('4', 'CD'),
#  (']', 'NN'),
#  ('.', '.'),
#  ('The', 'DT'),
#  ('following', 'VBG'),
#  ('users', 'NNS'),
#  ('contributed', 'VBD'),
#  ('to', 'TO'),
#  ('this', 'DT'),
#  ('book', 'NN'),
#  (':', ':'),
#  ('CES1596', 'NNP'),
#  ('Christophorus~lawikisource', 'NNP'),
#  ('Accurimbono', 'NNP'),
#  ('Barbaking', 'NNP'),
#  ('ShakespeareFan00', 'NNP'),
#  ('Piero~lawikisource', 'NNP'),
#  ('Jredmond', 'NNP'),
#  ('SSilent', 'NNP'),
#  ('Demetrius', 'NNP'),
#  ('Talpa', 'NNP'),
#  ('Lew', 'NNP'),
#  ('XXI', 'NNP'),
#  ('Nicole', 'NNP'),
#  ('Sharp', 'NNP'),
#  ('Matthead', 'NNP'),
#  ('Daniele', 'NNP'),
#  ('Pugliesi', 'NNP'),
#  ('Svdmolen', 'NNP'),
#  ('*', 'NNP'),
#  ('*', 'NNP'),
#  ('*', 'NNP'),
#  ('↑', 'NNP'),
#  ('https', 'NN'),
#  (':', ':'),
#  ('//wikisource.org', 'JJ'),
#  ('↑', 'JJ'),
#  ('https', 'NN'),
#  (':', ':'),
#  ('//www.creativecommons.org/licenses/by-sa/3.0', 'JJ'),
#  ('↑', 'NN'),
#  ('https', 'NN'),
#  (':', ':'),
#  ('//www.gnu.org/copyleft/fdl.html', 'JJ'),
#  ('↑', 'JJ'),
#  ('https', 'NN'),
#  (':', ':'),
#  ('//wikisource.org/wiki/Wikisource', 'NN'),
#  (':', ':'),
#  ('Scriptorium', 'NN'))

# %%
### GRADED
named_entities = []


    
# YOUR CODE HERE
#raise NotImplementedError()
#named_entities = tuple(words_pos)
for word in nltk.ne_chunk(words_pos):
    if hasattr(word, 'label'):
        named_entities.append((' '.join(c[0] for c in word.leaves()), word.label()))

### ANSWER CHECK
print(type(named_entities))
print(named_entities[:5])
# Out:
# <class 'list'>
# [('Philosophiae', 'GSP'), ('Naturalis Principia Mathematica Isaacus Newtonus', 'PERSON'), ('Wikisource', 'GPE'), ('INDEX Tituli', 'ORGANIZATION'), ('Auctoris', 'GPE')]

# %% [markdown]
# [Back to top](#-Index)
#
# ### Problem 5
#
# #### Removing People
#
# **5 Points**
#
# Use the `named_entities` list to include only entities labeled `GPE` and create a list of these words lowercased as `places` below.

# %%
#named_entities[]
[t[0].lower() for t in named_entities if t[1] == 'GPE']
#[t[1] for t in named_entities]
# Out:
# ['wikisource',
#  'auctoris',
#  'umbilico',
#  'orbibus',
#  'orbibus',
#  'superficiebus',
#  'mediis',
#  'fluida']

# %%
### GRADED
places = []


    
# YOUR CODE HERE
#raise NotImplementedError()
places = [t[0].lower() for t in named_entities if t[1] == 'GPE']

### ANSWER CHECK
print(type(places))
print(places[:5])
# Out:
# <class 'list'>
# ['wikisource', 'auctoris', 'umbilico', 'orbibus', 'orbibus']

# %% [markdown]
# [Back to top](#-Index)
#
# ### Problem 6
#
# #### Removing stopwords
#
# **5 Points**
#
# Use the list `places` to remove all stopwords.  Assign these words as a list to `no_stops` below.

# %%
from nltk.corpus import stopwords

# %%
import numpy as np
np.setdiff1d(words_pos, places)
# Out:
# array(['#', '&', "'s", '(', ')', '*', ',', '.', '...', '//wikisource.org',
#        '//wikisource.org/wiki/Wikisource',
#        '//www.creativecommons.org/licenses/by-sa/3.0',
#        '//www.gnu.org/copyleft/fdl.html', '//www.pgdp.net', '1', '1686',
#        '1687', '2', '2009', '2022', '28233', '3', '3.0', '4', '5', '8859',
#        ':', 'AD', 'APPENDIX', 'AUSPICIIS', 'About', 'Accurimbono', 'Anno',
#        'April', 'Apsidum', 'Ascensu', 'Attribution-ShareAlike',
#        'Auctoris', 'Author', 'Autore', 'Axiomata', 'Barbaking',
#        'Bibliopolas', 'CAROLO', 'CC', 'CD', 'CES1596', 'CORPORUM',
#        'Cantab', 'Character', 'Christophorus~lawikisource', 'Circulari',
#        'Coll', 'Commons', 'Conicis', 'Corporum', 'Creative', 'D.D.D',
#        'DE', 'DI', 'DT', 'Daniele', 'Date', 'De', 'Definitiones',
#        'Demetrius', 'Densitate', 'Descensu', 'Distributed', 'During',
#        'EBOOK', 'EBook', 'ET', 'Edkins', 'Elliptieorum', 'Exported',
#        'FDL', 'FLORENTI', 'FUNDATÆ', 'FW', 'Fluida', 'Fluidorum',
#        'Funependulorum', 'GNU', 'GUTENBERG', 'Gutenberg', 'Hydrostatica',
#        'Hyperbolieorum', 'I', 'II', 'III', 'ILLUSTRISSIMÆ', 'IMPRIMATUR',
#        'IN', 'INDEX', 'IS', 'ISO', 'IV', 'IX', 'Ingram', 'Isaac',
#        'Isaacus', 'JACOBI', 'JJ', 'Jonathan', 'Josephi', 'Jredmond',
#        'Julii', 'Jussu', 'Keith', 'LIBER', 'LONDINI', 'Language', 'Latin',
#        'Leges', 'Lew', 'License', 'Lucasiano', 'MATHEMATICA', 'MD',
#        'MDCLXXXVII', 'MONARCHÆ', 'MOTU', 'MUNDI', 'Magni', 'March',
#        'Mathematica', 'Matheseos', 'Matthead', 'Mediis', 'Methodo',
#        'Minimorum', 'Motu', 'Motus', 'Motuum', 'NATURALIS', 'NEWTON',
#        'NN', 'NNP', 'NNS', 'Naturalis', 'Newton', 'Newtonus', 'Nicole',
#        'OF', 'Online', 'Orbibus', 'Orbium', 'PEPYS', 'PHILOSOPHIAE',
#        'PHILOSOPHIAM', 'PHILOSOPHIÆ', 'POTENTISSIMI', 'PRIMUS',
#        'PRINCIPIA', 'PROJECT', 'PROMOVENDAM', 'PRP', 'PRP$', 'PRÆSES',
#        'Parabolieorum', 'Philosophiae', 'Piero~lawikisource', 'Principia',
#        'Produced', 'Professore', 'Project', 'Projectilium',
#        'Proofreading', 'Prostat', 'Præstantissimi', 'Pugliesi', 'RB',
#        'REGALI', 'REGE', 'Reg', 'Regalis', 'Regiæ', 'Release', 'S.',
#        'SECT', 'SECUNDUS', 'SOCIETATI', 'SSilent', 'START', 'SYSTEMATE',
#        'Scriptorium', 'Serenissimo', 'ShakespeareFan00', 'Sharp', 'Soc',
#        'Societatis', 'Sodali', 'Sphærieorum', 'Streater', 'Superficiebus',
#        'Svdmolen', 'TERTIUS', 'THIS', 'TO', 'Talpa', 'Team', 'The',
#        'This', 'Title', 'Tituli', 'Tractatum', 'Trin', 'Typis',
#        'Umbilico', 'Umbilicus', 'Unported', 'V.', 'VB', 'VBD', 'VBG',
#        'VBN', 'VBP', 'VBZ', 'VI', 'VII', 'VIII', 'Veribus', 'Viri',
#        'Viribus', 'Virium', 'We', 'Wikisource', 'X', 'XI', 'XII', 'XIII',
#        'XIV', 'XXI', 'You', '[', ']', 'a', 'ac', 'accessible', 'ad',
#        'agitantur', 'agitata', 'alicujus', 'almost', 'and', 'any',
#        'anyone', 'anywhere', 'apud', 'are', 'at', 'attracti',
#        'attractivis', 'away', 'book', 'books', 'built', 'by', 'can',
#        'cen', 'centripetarum', 'centripetis', 'choice', 'circulari',
#        'cis', 'collection', 'comes', 'commercial', 'committed',
#        'compressione', 'constantly', 'contributed', 'copy', 'copyrighted',
#        'corpora', 'corporis', 'corporum', 'cost', 'datis', 'dato',
#        'datur', 'dentibus', 'deque', 'developing', 'digital',
#        'distribute', 'duplicata', 'e-book', 'e-books', 'eBook',
#        'eccentri', 'edition', 'ejusdem', 'encoding', 'errors', 'every',
#        'ex', 'exploitation', 'following', 'for', 'free', 'from', 'give',
#        'http', 'https', 'humillime', 'hunc', 'in', 'included',
#        'including', 'inventione', 'is', 'it', 'kind', 'lectorem',
#        'letters', 'library', 'license', 'looking', 'made', 'magazines',
#        'may', 'members', 'mobilibus', 'motu', 'multilingual', 'mutuo',
#        'neuter', 'new', 'no', 'non', 'not', 'novels', 'of', 'on',
#        'online', 'or', 'our', 'page', 'pagina', 'partes', 'partim', 'pe',
#        'per', 'plures', 'poems', 'possible', 'primarum', 'propagato',
#        'præfatio', 'publications', 'published', 'purpose', 'quibus',
#        'quibuscunque', 'quæ', 'ratione', 'rationum', 're', 'realization',
#        'reciproco', 'rectilineo', 'report', 'resistentia',
#        'resistentibus', 'resistitur', 'resistuntur', 'restrictions',
#        'revolvuntur', 'rum', 'se', 'sectionibus', 'set', 'singulas',
#        'sive', 'some', 'starting', 'ten', 'tentium', 'terms', 'that',
#        'the', 'them', 'this', 'those', 'to', 'tripetis', 'ubi', 'ultima',
#        'under', 'use', 'users', 'velocitatis', 'velocitatum', 'vis',
#        'volunteers', 'we', 'whatsoever', 'with', 'works',
#        'www.gutenberg.org', 'your', '↑'], dtype='<U44')

# %%
### GRADED
no_stops = ''


    
# YOUR CODE HERE
#raise NotImplementedError()
no_stops = [t for t in places if not t in stopwords.words('english')]

### ANSWER CHECK
print(type(no_stops))
print(no_stops)
# Out:
# <class 'list'>
# ['wikisource', 'auctoris', 'umbilico', 'orbibus', 'orbibus', 'superficiebus', 'mediis', 'fluida']
