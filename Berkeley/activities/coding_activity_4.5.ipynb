# %% [markdown]
# ### String Methods with `pandas`
#
#
# **Expected Time: 60 Minutes**
#
# **Total Points: 20**
#
#
# For this activity, you will focus on using string methods on `pandas` series.  Following the examples from video 4.8, a wikipedia page on the states of the russian federation will be the dataset.  Below is a map of the boundaries for the states.
#
# #### Index:
#
# - [Problem 1](#Problem-1)
# - [Problem 2](#Problem-2)
# - [Problem 3](#Problem-3)
# - [Problem 4](#Problem-4)
#
# ![](https://upload.wikimedia.org/wikipedia/commons/thumb/7/7d/Map_of_federal_subjects_of_Russia_%282014%29.svg/1380px-Map_of_federal_subjects_of_Russia_%282014%29.svg.png)

# %% [markdown]
# ### Getting the Data
#
# Below, we access the data directly using the url and the `read_html` method from `pandas`.  This method reads any table from a web url in as a list of dataframes.  The data we are interested in is located in the fifth table on the page so we index the list of data accordingly below.

# %%
import pandas as pd

# %%
russian_states = pd.read_csv('data/russian_states.csv', index_col = 0)

# %%
russian_states.head()
# Out:
#    Code                        Name Capital/Administrative centre[a]  Flag  \
# 0     1         Adygea, Republic of                           Maykop   NaN
# 1     2  Bashkortostan, Republic of                              Ufa   NaN
# 2     3       Buryatia, Republic of                         Ulan-Ude   NaN
# 3     4              Altai Republic                    Gorno-Altaysk   NaN
# 4     5       Dagestan, Republic of                      Makhachkala   NaN
#
#    Coatof arms      Type Federal district Economic region Area(km2)[16]  \
# 0          NaN  republic         Southern  North Caucasus          7600
# 1          NaN  republic            Volga            Ural        143600
# 2          NaN  republic      Far Eastern   East Siberian        351300
# 3          NaN  republic         Siberian   West Siberian         92600
# 4          NaN  republic  North Caucasian  North Caucasus         50300
#
#   Population[17]  Populationdensity(/km2)  Yearestablished
# 0         447109                    58.83             1922
# 1        4104336                    28.58             1919
# 2         981238                     2.79             1923
# 3         202947                     2.19             1922
# 4        2576531                    51.22             1921

# %% [markdown]
# [Back to top](#Index:)
#
# ### Problem 1
#
# #### Using the `contains` method
#
# **5 Points**
#
# Use the string method `contains` to subset the data based on entries in the Economic Region column containing `Siberian`.  Assign your response as a DataFrame to `ans1` below.

# %%
russian_states[russian_states['Economic region'].str.contains('Siberian')]
# Out:
#     Code                                   Name  \
# 2      3                  Buryatia, Republic of
# 3      4                         Altai Republic
# 16    17                          Tuva Republic
# 18    19                 Khakassia, Republic of
# 21    22                             Altai Krai
# 23    24                       Krasnoyarsk Krai
# 37    38                         Irkutsk Oblast
# 41    42                        Kemerovo Oblast
# 53    54                     Novosibirsk Oblast
# 54    55                            Omsk Oblast
# 69    70                           Tomsk Oblast
# 71    72                          Tyumen Oblast
# 74    75                       Zabaykalsky Krai
# 80    81  Khanty–Mansi Autonomous Okrug – Yugra
# 82    83         Yamalo-Nenets Autonomous Okrug
#
#          Capital/Administrative centre[a]  Flag  Coatof arms  \
# 2                                Ulan-Ude   NaN          NaN
# 3                           Gorno-Altaysk   NaN          NaN
# 16                                  Kyzyl   NaN          NaN
# 18                                 Abakan   NaN          NaN
# 21                                Barnaul   NaN          NaN
# 23                            Krasnoyarsk   NaN          NaN
# 37                                Irkutsk   NaN          NaN
# 41                               Kemerovo   NaN          NaN
# 53                            Novosibirsk   NaN          NaN
# 54                                   Omsk   NaN          NaN
# 69                                  Tomsk   NaN          NaN
# 71                                 Tyumen   NaN          NaN
# 74                                  Chita   NaN          NaN
# 80  Khanty-Mansiysk(Largest city: Surgut)   NaN          NaN
# 82      Salekhard(Largest city: Noyabrsk)   NaN          NaN
#
#                 Type Federal district Economic region Area(km2)[16]  \
# 2           republic      Far Eastern   East Siberian        351300
# 3           republic         Siberian   West Siberian         92600
# 16          republic         Siberian   East Siberian        170500
# 18          republic         Siberian   East Siberian         61900
# 21              krai         Siberian   West Siberian        169100
# 23              krai         Siberian   East Siberian       2339700
# 37            oblast         Siberian   East Siberian        767900
# 41            oblast         Siberian   West Siberian         95500
# 53            oblast         Siberian   West Siberian        178200
# 54            oblast         Siberian   West Siberian        139700
# 69            oblast         Siberian   West Siberian        316900
# 71            oblast             Ural   West Siberian        143520
# 74              krai      Far Eastern   East Siberian        431500
# 80  autonomous okrug             Ural   West Siberian        523100
# 82  autonomous okrug             Ural   West Siberian        750300
#
#    Population[17]  Populationdensity(/km2)  Yearestablished
# 2          981238                     2.79             1923
# 3          202947                     2.19             1922
# 16         305510                     1.79             1944
# 18         546072                     8.82             1930
# 21        2607426                    15.42             1937
# 23        2966042                     1.27             1934
# 37        2581705                     3.36             1937
# 41        2899142                    30.36             1943
# 53        2692251                    15.11             1937
# 54        2079220                    14.88             1934
# 69        1046039                     3.30             1944
# 71        3264841                    22.75             1944
# 74        1155346                     2.68             2008
# 80        1432817                     2.74             1930
# 82         507006                     0.68             1930

# %%
### GRADED

ans1 = None

# YOUR CODE HERE
#raise NotImplementedError()
ans1 = russian_states[russian_states['Economic region'].str.contains('Siberian')]
# Answer check
print(ans1.shape)
ans1.head()
# Out:
# (15, 12)
#     Code                    Name Capital/Administrative centre[a]  Flag  \
# 2      3   Buryatia, Republic of                         Ulan-Ude   NaN
# 3      4          Altai Republic                    Gorno-Altaysk   NaN
# 16    17           Tuva Republic                            Kyzyl   NaN
# 18    19  Khakassia, Republic of                           Abakan   NaN
# 21    22              Altai Krai                          Barnaul   NaN
#
#     Coatof arms      Type Federal district Economic region Area(km2)[16]  \
# 2           NaN  republic      Far Eastern   East Siberian        351300
# 3           NaN  republic         Siberian   West Siberian         92600
# 16          NaN  republic         Siberian   East Siberian        170500
# 18          NaN  republic         Siberian   East Siberian         61900
# 21          NaN      krai         Siberian   West Siberian        169100
#
#    Population[17]  Populationdensity(/km2)  Yearestablished
# 2          981238                     2.79             1923
# 3          202947                     2.19             1922
# 16         305510                     1.79             1944
# 18         546072                     8.82             1930
# 21        2607426                    15.42             1937

# %% [markdown]
# [Back to top](#Index:)
#
# ### Problem 2
#
# #### Using the `startswith` method
#
# **5 Points**
#
# Subset the data based on entries in the Economic region column that start with `North`.  Assign your answer as a DataFrame to `ans2` below.

# %%
### GRADED

ans2 = None

# YOUR CODE HERE
#raise NotImplementedError()
ans2 = russian_states[russian_states['Economic region'].str.startswith('North')]

# Answer check
print(ans2.shape)
ans2.head()
# Out:
# (22, 12)
#    Code                        Name Capital/Administrative centre[a]  Flag  \
# 0     1         Adygea, Republic of                           Maykop   NaN
# 4     5       Dagestan, Republic of                      Makhachkala   NaN
# 5     6     Ingushetia, Republic of      Magas(Largest city: Nazran)   NaN
# 6     7   Kabardino-Balkar Republic                          Nalchik   NaN
# 8     9  Karachay-Cherkess Republic                        Cherkessk   NaN
#
#    Coatof arms      Type Federal district Economic region Area(km2)[16]  \
# 0          NaN  republic         Southern  North Caucasus          7600
# 4          NaN  republic  North Caucasian  North Caucasus         50300
# 5          NaN  republic  North Caucasian  North Caucasus          4000
# 6          NaN  republic  North Caucasian  North Caucasus         12500
# 8          NaN  republic  North Caucasian  North Caucasus         14100
#
#   Population[17]  Populationdensity(/km2)  Yearestablished
# 0         447109                    58.83             1922
# 4        2576531                    51.22             1921
# 5         467294                   116.82             1992
# 6         901494                    72.12             1936
# 8         439470                    31.17             1957

# %% [markdown]
# [Back to top](#Index:)
#
# ### Problem 3: Using the `upper` method
#
# **5 Points**
#
# Use the `upper` method to create a series with the Federal District column all uppercased.  Assign your response as a Series to `ans3` below.

# %%
### GRADED

ans3 = None

# YOUR CODE HERE
#raise NotImplementedError()
ans3 = russian_states['Federal district'].str.upper()

# Answer check
print(type(ans3))
ans3.head()
# Out:
# <class 'pandas.core.series.Series'>
# 0           SOUTHERN
# 1              VOLGA
# 2        FAR EASTERN
# 3           SIBERIAN
# 4    NORTH CAUCASIAN
# Name: Federal district, dtype: object

# %% [markdown]
# [Back to top](#Index:)
#
# ### Problem 4
#
# #### Examining the Population
#
# **5 Points**
#
#
# Much like the example in the videos, the Population column contains problematic characters that need to be replaced before the column can be converted to a float datatype.  Replace these values and convert the Population column to float datatypes.  Assign the your response as a series to `ans4` below.

# %%
russian_states.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 85 entries, 0 to 84
# Data columns (total 12 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   Code                              85 non-null     int64
#  1   Name                              85 non-null     object
#  2   Capital/Administrative centre[a]  85 non-null     object
#  3   Flag                              0 non-null      float64
#  4   Coatof arms                       0 non-null      float64
#  5   Type                              85 non-null     object
#  6   Federal district                  85 non-null     object
#  7   Economic region                   85 non-null     object
#  8   Area(km2)[16]                     85 non-null     object
#  9   Population[17]                    85 non-null     object
#  10  Populationdensity(/km2)           85 non-null     float64
#  11  Yearestablished                   85 non-null     int64
# dtypes: float64(3), int64(2), object(7)
# memory usage: 8.6+ KB

# %%
russian_states['Population[17]'].str.replace(",", "").str.replace("\[\d*\]", "")
# Out:
# /var/folders/y8/q3tyf2ls6hdcr5jmw1zdr2f40000gp/T/ipykernel_70226/2925385487.py:1: FutureWarning: The default value of regex will change from True to False in a future version.
#   russian_states['Population[17]'].str.replace(",", "").str.replace("\[\d*\]", "")
# 0      447109
# 1     4104336
# 2      981238
# 3      202947
# 4     2576531
#        ...
# 80    1432817
# 81      53824
# 82     507006
# 83    1966801
# 84     379200
# Name: Population[17], Length: 85, dtype: object

# %%
help(pd.to_numeric)
# Out:
# Help on function to_numeric in module pandas.core.tools.numeric:
#
# to_numeric(arg, errors='raise', downcast=None)
#     Convert argument to a numeric type.
#
#     The default return dtype is `float64` or `int64`
#     depending on the data supplied. Use the `downcast` parameter
#     to obtain other dtypes.
#
#     Please note that precision loss may occur if really large numbers
#     are passed in. Due to the internal limitations of `ndarray`, if
#     numbers smaller than `-9223372036854775808` (np.iinfo(np.int64).min)
#     or larger than `18446744073709551615` (np.iinfo(np.uint64).max) are
#     passed in, it is very likely they will be converted to float so that
#     they can stored in an `ndarray`. These warnings apply similarly to
#     `Series` since it internally leverages `ndarray`.
#
#     Parameters
#     ----------
#     arg : scalar, list, tuple, 1-d array, or Series
#         Argument to be converted.
#     errors : {'ignore', 'raise', 'coerce'}, default 'raise'
#         - If 'raise', then invalid parsing will raise an exception.
#         - If 'coerce', then invalid parsing will be set as NaN.
#         - If 'ignore', then invalid parsing will return the input.
#     downcast : {'integer', 'signed', 'unsigned', 'float'}, default None
#         If not None, and if the data has been successfully cast to a
#         numerical dtype (or if the data was numeric to begin with),
#         downcast that resulting data to the smallest numerical dtype
#         possible according to the following rules:
#
#         - 'integer' or 'signed': smallest signed int dtype (min.: np.int8)
#         - 'unsigned': smallest unsigned int dtype (min.: np.uint8)
#         - 'float': smallest float dtype (min.: np.float32)
#
#         As this behaviour is separate from the core conversion to
#         numeric values, any errors raised during the downcasting
#         will be surfaced regardless of the value of the 'errors' input.
#
#         In addition, downcasting will only occur if the size
#         of the resulting data's dtype is strictly larger than
#         the dtype it is to be cast to, so if none of the dtypes
#         checked satisfy that specification, no downcasting will be
#         performed on the data.
#
#     Returns
#     -------
#     ret
#         Numeric if parsing succeeded.
#         Return type depends on input.  Series if Series, otherwise ndarray.
#
#     See Also
#     --------
#     DataFrame.astype : Cast argument to a specified dtype.
#     to_datetime : Convert argument to datetime.
#     to_timedelta : Convert argument to timedelta.
#     numpy.ndarray.astype : Cast a numpy array to a specified type.
#     DataFrame.convert_dtypes : Convert dtypes.
#
#     Examples
#     --------
#     Take separate series and convert to numeric, coercing when told to
#
#     >>> s = pd.Series(['1.0', '2', -3])
#     >>> pd.to_numeric(s)
#     0    1.0
#     1    2.0
#     2   -3.0
#     dtype: float64
#     >>> pd.to_numeric(s, downcast='float')
#     0    1.0
#     1    2.0
#     2   -3.0
#     dtype: float32
#     >>> pd.to_numeric(s, downcast='signed')
#     0    1
#     1    2
#     2   -3
#     dtype: int8
#     >>> s = pd.Series(['apple', '1.0', '2', -3])
#     >>> pd.to_numeric(s, errors='ignore')
#     0    apple
#     1      1.0
#     2        2
#     3       -3
#     dtype: object
#     >>> pd.to_numeric(s, errors='coerce')
#     0    NaN
#     1    1.0
#     2    2.0
#     3   -3.0
#     dtype: float64
#
#     Downcasting of nullable integer and floating dtypes is supported:
#
#     >>> s = pd.Series([1, 2, 3], dtype="Int64")
#     >>> pd.to_numeric(s, downcast="integer")
#     0    1
#     1    2
#     2    3
#     dtype: Int8
#     >>> s = pd.Series([1.0, 2.1, 3.0], dtype="Float64")
#     >>> pd.to_numeric(s, downcast="float")
#     0    1.0
#     1    2.1
#     2    3.0
#     dtype: Float32

# %%
### GRADED

ans4 = None

# YOUR CODE HERE
#raise NotImplementedError()
ans4 = pd.to_numeric(russian_states['Population[17]'].str.replace(",", "").str.replace("\[\d*\]", "")).astype('float')

# Answer check
print(type(ans4))
ans4.head()
# Out:
# <class 'pandas.core.series.Series'>
# /var/folders/y8/q3tyf2ls6hdcr5jmw1zdr2f40000gp/T/ipykernel_70226/3280796175.py:7: FutureWarning: The default value of regex will change from True to False in a future version.
#   ans4 = pd.to_numeric(russian_states['Population[17]'].str.replace(",", "").str.replace("\[\d*\]", "")).astype('float')
# 0     447109.0
# 1    4104336.0
# 2     981238.0
# 3     202947.0
# 4    2576531.0
# Name: Population[17], dtype: float64
